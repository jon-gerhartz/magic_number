# %%
import pandas as pd
import numpy as np

cleaned = pd.read_csv("C:/Users/jgerhartz/projects/playoffs/static/csv/new.csv" )
raw = pd.read_csv("test.csv")

#create list of non data rows
non_data = [1,7,13,19,20,21,27,33]
raw_rows = raw.drop(non_data, axis=0)
drop_cols = ["Unnamed: 0"]
raw_cols = raw_rows.drop(drop_cols,axis=1)

# %%
raw_cols.head()
# Out:
#    Unnamed: 0_level_0     Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0  Unnamed: 0_level_1                     Tm                 Lg
# 2                   1         Atlanta Braves                 NL
# 3                   2   Washington Nationals                 NL
# 4                   3          New York Mets                 NL
# 5                   4  Philadelphia Phillies                 NL
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
# 0                  D                SRS               rSOS
# 2                  E                1.1                0.2
# 3                  E                1.5                0.3
# 4                  E                0.8                0.3
# 5                  E               -0.1                0.8
#
#    Unnamed: 6_level_0 Current Current.1  Unnamed: 9_level_0  ...  \
# 0  Unnamed: 6_level_1       W         L  Unnamed: 9_level_1  ...
# 2                 NaN      91        56                 NaN  ...
# ...

# %%
cleaned.head()
# Out:
#    Unnamed: 0             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                     Tm         Lg          D        SRS
# 1         1.0         Atlanta Braves         NL          E        1.1
# 2         2.0   Washington Nationals         NL          E        1.4
# 3         3.0          New York Mets         NL          E        0.7
# 4         4.0  Philadelphia Phillies         NL          E       -0.1
#
#   Unnamed: 5  Unnamed: 6 Current Current.1  Unnamed: 9  ... Unnamed: 20  \
# 0       rSOS         NaN       W         L         NaN  ...          WC
# 1        0.4         NaN      86        54         NaN  ...        4.4%
# 2        0.4         NaN      78        60         NaN  ...       93.3%
# 3        0.4         NaN      71        68         NaN  ...        5.9%
# 4        0.8         NaN      72        66         NaN  ...        4.3%
#
#   Unnamed: 21  Unnamed: 22 Unnamed: 23 Unnamed: 24  Unnamed: 25 Unnamed: 26  \
# ...
